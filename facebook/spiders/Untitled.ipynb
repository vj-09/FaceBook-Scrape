# %%
import pandas as pd

# %%
df =  pd.read_csv('fb_text.csv',index_col=0)

# %%
df
# Out:
#                  Name                                               Text  \
# 0         Vj Athithya                                                NaN
# 1     Kaviya Balaguru                              adutha kandupudipahhh
# 2         Vj Athithya                                 Tqqq Ur student ha
# 3         Vj Athithya                                           Eruklama
# 4     Kaviya Balaguru                                              venam
# 5         Vj Athithya                                                  Y
# 6         Vj Athithya                                  Soli thara matiya
# 7     Kaviya Balaguru                                 na gud teacher ila
# 8         Vj Athithya                                           Paravala
# 9     Kaviya Balaguru                                enna solli tharanum
# 10        Vj Athithya               How to be gud and perfect like kavya
# 11    Kaviya Balaguru                       na gud um ila perfect um ila
# ...
